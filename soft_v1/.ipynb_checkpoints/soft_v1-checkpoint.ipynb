# %%
import pandas as pd
from pyvpsolver import *
import numpy as np
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)

# %%
# Input Demand
df_order = pd.read_excel('Input_Bin_Requirements.xlsx', header=None)
df_order = df_order.dropna(axis=1, how='all')
df_order = df_order.iloc[2:,:]
order_q = df_order.loc[3, 1:].values.astype('int')
order_b = df_order.loc[4, 1:].values.astype('int')

# Input Inventory
df_inventory = pd.read_excel('Inputs_Inventory.xlsx', header=None)
inventory_header = df_inventory.iloc[3, :]
df_inventory.columns = inventory_header
df_inventory = df_inventory.iloc[4:, :]
inventory = sorted(df_inventory['Length (m)'].values.astype('int'))

# %%
# Solving

# 1/sqrt(x) cost Cs = ((1/np.sqrt(np.array(inventory)))*1000).astype('int')
# linear cost Cs = inventory
# quadratic cost Cs = np.array(inventory)*inventory

Ws = [[i] for i in inventory]
Cs = np.array(inventory)*inventory
Qs = [1]*len(inventory)
ws = [[[x]] for x in order_b]
b = order_q

instance = MVP(Ws, Cs, Qs, ws, b)
afg = AFG(instance)

output, solution = VPSolver.script("vpsolver_gurobi.sh", instance)
# Out:
# VPSolver 3.1.2, Copyright (C) 2013-2016, Filipe Brandao
# Build (method = -3)
#   #dp: 2077
#   Step-3' Graph: 373 vertices and 35490 arcs (0.01s)
#   Step-4' Graph: 371 vertices and 1602 arcs (0.02s)
#   #V4/#V3 = 0.99
#   #A4/#A3 = 0.05
# Ready! (0.02s)
# Copyright (C) 2013-2016, Filipe Brandao
#
# >>> vbp2afg...
# VPSolver 3.1.2, Copyright (C) 2013-2016, Filipe Brandao
# Build (method = -3)
#   #dp: 2077
#   Step-3' Graph: 373 vertices and 35490 arcs (0.01s)
#   Step-4' Graph: 371 vertices and 1602 arcs (0.01s)
#   #V4/#V3 = 0.99
#   #A4/#A3 = 0.05
# Ready! (0.01s)
#
# >>> afg2mps...
# VPSolver 3.1.2, Copyright (C) 2013-2016, Filipe Brandao
# Generating the .MPS model...DONE!
#
# >>> solving the MIP model using Gurobi...
# Note: different parameter settings may improve the performance substantially!
# Using license file /Users/alikhannurlanuly/gurobi.lic
# Set parameter MIPGap to value 0
# Set parameter MIPGapAbs to value 0.99999
# Set parameter Method to value 2
# Set parameter Heuristics to value 1
# Set parameter MIPFocus to value 1
# Set parameter LogFile to value gurobi.log
# Set parameter Presolve to value 1
# Set parameter Seed to value 1234
# Set parameter Threads to value 1
# Academic license - for non-commercial use only
#
# Gurobi Optimizer version 9.0.0 build v9.0.0rc2 (mac64)
# Copyright (c) 2019, Gurobi Optimization, LLC
#
# Read MPS format model from file /var/folders/q5/2gv25gs93z72n_55js_2dfhc0000gn/T/XXXXXXXXXX.LgHFrVAu/model.mps
# Reading time = 0.00 seconds
# ARCFLOW: 388 rows, 1602 columns, 4224 nonzeros
# Optimize a model with 388 rows, 1602 columns and 4224 nonzeros
# Model fingerprint: 0xba521369
# Variable types: 0 continuous, 1602 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [5e+03, 2e+05]
#   Bounds range     [1e+00, 3e+02]
#   RHS range        [8e+00, 3e+01]
# Presolve removed 63 rows and 72 columns
# Presolve time: 0.03s
# Presolved: 325 rows, 1530 columns, 4088 nonzeros
# Variable types: 0 continuous, 1530 integer (184 binary)
# Root barrier log...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 2.622e+03
#  Factor NZ  : 1.246e+04 (roughly 1 MByte of memory)
#  Factor Ops : 8.459e+05 (less than 1 second per iteration)
#  Threads    : 1
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   3.07070939e+08 -2.50036312e+09  5.16e+02 1.16e-10  2.99e+06     0s
#    1   6.67465659e+07 -9.78414516e+08  7.04e+01 1.14e+04  5.43e+05     0s
#    2   2.48338351e+07 -1.82985091e+08  1.39e+01 1.27e+02  9.73e+04     0s
#    3   1.96381456e+07 -2.42850492e+07  8.50e+00 4.19e-09  2.82e+04     0s
#    4   1.51188216e+07  6.78223978e+04  3.64e+00 4.07e-09  9.48e+03     0s
#    5   1.28236268e+07  4.42578996e+06  1.08e+00 3.03e-09  3.85e+03     0s
#    6   1.22722457e+07  9.33279854e+06  4.44e-01 1.86e-09  1.26e+03     0s
#    7   1.19989732e+07  1.09993270e+07  1.38e-01 4.42e-09  4.08e+02     0s
#    8   1.19445792e+07  1.14264220e+07  8.43e-02 6.52e-09  2.23e+02     0s
#    9   1.19014217e+07  1.16019437e+07  4.22e-02 7.22e-09  1.21e+02     0s
#   10   1.18735493e+07  1.17061297e+07  1.53e-02 8.85e-09  6.07e+01     0s
#   11   1.18597618e+07  1.18015471e+07  2.93e-03 5.70e-09  1.92e+01     0s
#   12   1.18524212e+07  1.17915693e+07  1.92e-03 4.77e-09  2.05e+01     0s
#   13   1.18465651e+07  1.18130745e+07  7.40e-04 2.33e-09  1.11e+01     0s
#   14   1.18442290e+07  1.18250520e+07  5.61e-04 5.12e-10  6.33e+00     0s
#   15   1.18353851e+07  1.18294193e+07  6.70e-05 4.50e-10  1.97e+00     0s
#   16   1.18331720e+07  1.18329935e+07  1.24e-06 5.89e-10  5.89e-02     0s
#   17   1.18330691e+07  1.18330689e+07  6.67e-12 4.66e-10  5.93e-05     0s
#   18   1.18330690e+07  1.18330690e+07  4.03e-12 4.66e-10  5.93e-08     0s
#   19   1.18330690e+07  1.18330690e+07  5.60e-12 5.28e-10  2.64e-12     0s
#
# Barrier solved model in 19 iterations and 0.15 seconds
# Optimal objective 1.18330690e+07
#
#
# Root relaxation: objective 1.183307e+07, 187 iterations, 0.07 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1.1833e+07    0   50          - 1.1833e+07      -     -    0s
#      0     0 1.1850e+07    0   64          - 1.1850e+07      -     -    0s
#      0     0 1.1854e+07    0   54          - 1.1854e+07      -     -    0s
#      0     0 1.1856e+07    0   73          - 1.1856e+07      -     -    0s
#      0     0 1.1859e+07    0   82          - 1.1859e+07      -     -    0s
#      0     0 1.1859e+07    0   76          - 1.1859e+07      -     -    0s
#      0     0 1.1859e+07    0   87          - 1.1859e+07      -     -    0s
#      0     0 1.1859e+07    0   87          - 1.1859e+07      -     -    0s
#      0     0 1.1859e+07    0   33          - 1.1859e+07      -     -    0s
#      0     0 1.1859e+07    0   25          - 1.1859e+07      -     -    0s
# H    0     0                    1.185894e+07 1.1859e+07  0.00%     -    0s
#      0     0 1.1859e+07    0   25 1.1859e+07 1.1859e+07  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   RLT: 1
#
# Explored 1 nodes (1399 simplex iterations) in 0.59 seconds
# Thread count was 1 (of 4 available processors)
#
# Solution count 1: 1.18589e+07
#
# Optimal solution found (tolerance 0.00e+00)
# Best objective 1.185893600000e+07, best bound 1.185893600000e+07, gap 0.0000%
#
# Wrote result file '/var/folders/q5/2gv25gs93z72n_55js_2dfhc0000gn/T/XXXXXXXXXX.LgHFrVAu/vars.sol'
#
#
# >>> vbpsol...
# VPSolver 3.1.2, Copyright (C) 2013-2016, Filipe Brandao
# Objective: 11858936
# Solution:
# Bins of type 1: 1
# 1 x [i=1]
# Bins of type 2: 1
# 1 x [i=1]
# Bins of type 3: 1
# 1 x [i=1]
# Bins of type 4: 1
# 1 x [i=1]
# Bins of type 5: 1
# 1 x [i=1]
# Bins of type 6: 1
# 1 x [i=1]
# Bins of type 7: 1
# 1 x [i=2]
# Bins of type 8: 1
# 1 x [i=2]
# Bins of type 9: 1
# 1 x [i=2]
# Bins of type 10: 1
# 1 x [i=2]
# Bins of type 11: 1
# 1 x [i=2]
# Bins of type 12: 1
# 1 x [i=2]
# Bins of type 13: 1
# 1 x [i=4]
# Bins of type 14: 1
# 1 x [i=5]
# Bins of type 15: 1
# 1 x [i=5]
# Bins of type 16: 1
# 1 x [i=5]
# Bins of type 17: 1
# 1 x [i=5]
# Bins of type 18: 1
# 1 x [i=6]
# Bins of type 19: 1
# 1 x [i=6]
# Bins of type 20: 1
# 1 x [i=7]
# Bins of type 21: 1
# 1 x [i=7]
# Bins of type 22: 1
# 1 x [i=8]
# Bins of type 23: 1
# 1 x [i=8]
# Bins of type 24: 1
# 1 x [i=8]
# Bins of type 25: 1
# 1 x [i=9]
# Bins of type 26: 1
# 1 x [i=9]
# Bins of type 27: 1
# 1 x [i=9]
# Bins of type 28: 1
# 1 x [i=10]
# Bins of type 29: 1
# 1 x [i=10]
# Bins of type 30: 1
# 1 x [i=10]
# Bins of type 31: 1
# 1 x [i=1, i=1]
# Bins of type 32: 1
# 1 x [i=11]
# Bins of type 33: 1
# 1 x [i=11]
# Bins of type 34: 1
# 1 x [i=11]
# Bins of type 35: 1
# 1 x [i=1, i=2]
# Bins of type 36: 1
# 1 x [i=11]
# Bins of type 37: 1
# 1 x [i=11]
# Bins of type 38: 1
# 1 x [i=11]
# Bins of type 39: 1
# 1 x [i=2, i=2]
# Bins of type 40: 1
# 1 x [i=2, i=2]
# Bins of type 41: 1
# 1 x [i=13]
# Bins of type 42: 1
# 1 x [i=13]
# Bins of type 43: 1
# 1 x [i=13]
# Bins of type 44: 1
# 1 x [i=2, i=3]
# Bins of type 45: 1
# 1 x [i=2, i=3]
# Bins of type 46: 1
# 1 x [i=2, i=3]
# Bins of type 47: 1
# 1 x [i=14]
# Bins of type 48: 1
# 1 x [i=14]
# Bins of type 49: 1
# 1 x [i=3, i=3]
# Bins of type 50: 1
# 1 x [i=3, i=3]
# Bins of type 51: 1
# 1 x [i=3, i=3]
# Bins of type 52: 1
# 1 x [i=3, i=3]
# Bins of type 53: 1
# 1 x [i=15]
# Bins of type 54: 1
# 1 x [i=15]
# Bins of type 55: 1
# 1 x [i=15]
# Bins of type 56: 1
# 1 x [i=3, i=4]
# Bins of type 57: 1
# 1 x [i=3, i=4]
# Bins of type 58: 1
# 1 x [i=16]
# Bins of type 59: 1
# 1 x [i=3, i=5]
# Bins of type 60: 1
# 1 x [i=3, i=5]
# Bins of type 61: 1
# 1 x [i=17]
# Bins of type 62: 1
# 1 x [i=17]
# Bins of type 63: 1
# 1 x [i=17]
# Bins of type 64: 1
# 1 x [i=2, i=7]
# Bins of type 65: 1
# 1 x [i=1, i=9]
# Bins of type 66: 1
# 1 x [i=1, i=9]
# Bins of type 67: 1
# 1 x [i=3, i=6]
# Bins of type 68: 1
# 1 x [i=3, i=6]
# Bins of type 69: 1
# 1 x [i=3, i=6]
# Bins of type 70: 1
# 1 x [i=2, i=9]
# Bins of type 71: 1
# 1 x [i=4, i=6]
# Bins of type 72: 1
# 1 x [i=2, i=12]
# Bins of type 73: 1
# 1 x [i=2, i=12]
# Bins of type 74: 1
# 1 x [i=2, i=12]
# Bins of type 75: 1
# 1 x [i=5, i=9]
# Bins of type 76: 1
# 1 x [i=5, i=9]
# Bins of type 77: 1
# 1 x [i=6, i=7]
# Bins of type 78: 1
# 1 x [i=6, i=7]
# Bins of type 79: 1
# 1 x [i=4, i=11]
# Bins of type 80: 1
# 1 x [i=7, i=7]
# Bins of type 81: 1
# 1 x [i=1, i=14]
# Bins of type 82: 1
# 1 x [i=5, i=11]
# Bins of type 83: 1
# 1 x [i=7, i=9]
# Bins of type 84: 1
# 1 x [i=7, i=9]
# Bins of type 85: 1
# 1 x [i=7, i=9]
# Bins of type 86: 1
# 1 x [i=5, i=12]
# Bins of type 87: 1
# 1 x [i=1, i=16]
# Bins of type 88: 1
# 1 x [i=4, i=13]
# Bins of type 89: 1
# 1 x [i=2, i=15]
# Bins of type 90: 1
# 1 x [i=2, i=15]
# Bins of type 91: 1
# 1 x [i=6, i=11]
# Bins of type 92: 1
# 1 x [i=6, i=11]
# Bins of type 93: 1
# 1 x [i=2, i=3, i=4]
# Bins of type 94: 1
# 1 x [i=7, i=11]
# Bins of type 95: 1
# 1 x [i=4, i=14]
# Bins of type 96: 1
# 1 x [i=4, i=14]
# Bins of type 97: 1
# 1 x [i=9, i=11]
# Bins of type 98: 1
# 1 x [i=6, i=13]
# Bins of type 99: 1
# 1 x [i=9, i=11]
# Bins of type 100: 1
# 1 x [i=10, i=11]
# Bins of type 101: 1
# 1 x [i=10, i=11]
# Bins of type 102: 1
# 1 x [i=4, i=16]
# Bins of type 103: 1
# 1 x [i=7, i=13]
# Bins of type 104: 1
# 1 x [i=7, i=13]
# Bins of type 105: 1
# 1 x [i=6, i=14]
# Bins of type 106: 1
# 1 x [i=10, i=12]
# Bins of type 107: 1
# 1 x [i=10, i=12]
# Bins of type 108: 1
# 1 x [i=5, i=16]
# Bins of type 109: 1
# 1 x [i=5, i=16]
# Bins of type 110: 1
# 1 x [i=1, i=1, i=1, i=2]
# Bins of type 111: 1
# 1 x [i=5, i=16]
# Bins of type 112: 1
# 1 x [i=5, i=16]
# Bins of type 113: 1
# 1 x [i=6, i=15]
# Bins of type 114: 1
# 1 x [i=6, i=15]
# Bins of type 115: 1
# 1 x [i=6, i=15]
# Bins of type 116: 1
# 1 x [i=6, i=15]
# Bins of type 117: 1
# 1 x [i=5, i=17]
# Bins of type 118: 1
# 1 x [i=6, i=16]
# Bins of type 119: 1
# 1 x [i=6, i=16]
# Bins of type 120: 1
# 1 x [i=1, i=4, i=10]
# Bins of type 121: 1
# 1 x [i=7, i=16]
# Bins of type 122: 1
# 1 x [i=7, i=16]
# Bins of type 123: 1
# 1 x [i=7, i=16]
# Bins of type 124: 1
# 1 x [i=10, i=14]
# Bins of type 125: 1
# 1 x [i=9, i=15]
# Bins of type 126: 1
# 1 x [i=11, i=14]
# Bins of type 127: 1
# 1 x [i=11, i=14]
# Bins of type 128: 1
# 1 x [i=10, i=15]
# Bins of type 129: 1
# 1 x [i=10, i=15]
# Bins of type 130: 1
# 1 x [i=3, i=4, i=10]
# Bins of type 131: 1
# 1 x [i=12, i=14]
# Bins of type 132: 1
# 1 x [i=13, i=13]
# Bins of type 133: 1
# 1 x [i=13, i=13]
# Bins of type 134: 1
# 1 x [i=13, i=13]
# Bins of type 135: 1
# 1 x [i=12, i=15]
# Bins of type 136: 1
# 1 x [i=3, i=6, i=9]
# Bins of type 137: 1
# 1 x [i=13, i=14]
# Bins of type 138: 1
# 1 x [i=13, i=14]
# Bins of type 139: 1
# 1 x [i=5, i=5, i=9]
# Bins of type 140: 1
# 1 x [i=14, i=14]
# Bins of type 141: 1
# 1 x [i=13, i=16]
# Bins of type 142: 1
# 1 x [i=3, i=7, i=11]
# Bins of type 143: 1
# 1 x [i=14, i=16]
# Bins of type 144: 1
# 1 x [i=14, i=16]
# Bins of type 145: 1
# 1 x [i=15, i=15]
# Bins of type 146: 1
# 1 x [i=6, i=8, i=8]
# Bins of type 147: 1
# 1 x [i=6, i=8, i=8]
# Bins of type 148: 1
# 1 x [i=15, i=16]
# Bins of type 149: 1
# 1 x [i=2, i=10, i=12]
# Bins of type 150: 1
# 1 x [i=4, i=9, i=11]
# Bins of type 151: 1
# 1 x [i=16, i=16]
# Bins of type 152: 1
# 1 x [i=16, i=16]
# Bins of type 153: 1
# 1 x [i=4, i=6, i=13]
# Bins of type 154: 1
# 1 x [i=16, i=17]
# Bins of type 155: 1
# 1 x [i=4, i=6, i=14]
# Bins of type 156: 1
# 1 x [i=17, i=17]
# Bins of type 157: 1
# 1 x [i=6, i=7, i=13]
# Bins of type 158: 1
# 1 x [i=6, i=6, i=14]
# Bins of type 159: 1
# 1 x [i=6, i=10, i=12]
# Bins of type 160: 1
# 1 x [i=3, i=13, i=13]
# Bins of type 161: 1
# 1 x [i=5, i=12, i=13]
# Bins of type 162: 1
# 1 x [i=10, i=10, i=12]
# Bins of type 163: 1
# 1 x [i=6, i=12, i=14]
# Bins of type 164: 1
# 1 x [i=3, i=13, i=17]
# Bins of type 165: 1
# 1 x [i=3, i=14, i=16]
# Bins of type 166: 1
# 1 x [i=8, i=13, i=13]
# Bins of type 167: 1
# 1 x [i=3, i=4, i=7, i=11]
# Bins of type 168: 1
# 1 x [i=6, i=12, i=16]
# Bins of type 169: 1
# 1 x [i=10, i=12, i=14]
# Bins of type 170: 1
# 1 x [i=12, i=12, i=14]
# Bins of type 171: 1
# 1 x [i=7, i=15, i=15]
# Bins of type 172: 1
# 1 x [i=10, i=14, i=15]
# Bins of type 173: 1
# 1 x [i=7, i=15, i=17]

# %%
# Formatting Solution
df_solution = pd.DataFrame(solution[1])
df_solution.columns = ['raw_solution']

def get_scrap(x):
    if x < min(order_b):
        return x
    else:
        return 0

def get_bin_size(x):
    if x != None:
        x = x[1]
        result = []
        for i in x:
            result.append(order_b[i[0]])
        return result
    else:
        return 0

def get_leftover(x):
    if x[1] == 0:
        return 0
    else:
        return x[0] - sum(x[1])
    
df_solution['wire_len'] = inventory
df_solution['bins'] = df_solution.apply(lambda x: get_bin_size(x[0]), axis = 1)
df_solution = df_solution.drop(columns='raw_solution')
df_solution['leftover'] = df_solution.apply(lambda x: get_leftover(x) ,axis = 1)
df_solution['scrap'] = df_solution.apply(lambda x: get_scrap(x[2]), axis=1)

bin_dict = {}
for i in range(1, len(order_b)+1):
    df_solution['bin_'+str(i)] = 0
    bin_dict[order_b[i-1]] = 'bin_'+str(i)
    
for index, row in enumerate(df_solution.values):
    allocated_bins = row[1]
    if type(allocated_bins) == list:
        for i in allocated_bins:
            bin_id = bin_dict[i]
            df_solution[bin_id][index]+=1
            
df_solution.to_excel('solution.xlsx')
# Out:
# /Users/alikhannurlanuly/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
