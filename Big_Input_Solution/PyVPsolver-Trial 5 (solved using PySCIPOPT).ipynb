# %%
import pandas as pd
from pyvpsolver import *

# source used https://github.com/fdabrandao/vpsolver

# %% [markdown]
# # Preprocess

# %%
df_orders = pd.read_csv('demand_big.csv', delimiter='\t')
df_orders.columns = ['bin_length', 'quantity', 'subtotal']
orders_length = df_orders['bin_length'].values
orders_q = df_orders['quantity'].values


df_available = pd.read_csv('actual_big.csv', delimiter='\t')
available_length = df_available['wire_length'].values
available_q = df_available['quantity'].values

def BinPacking(w, q):
    s=[]
    for j in range(len(w)):
        for i in range(q[j]):
            s.append(w[j])
    return s

actual_length = BinPacking(available_length, available_q)
actual_length = [[i]for i in actual_length]
Ws = actual_length
Cs = [1]*len(actual_length)
Qs = [1]*len(actual_length)
ws = [[[x]] for x in orders_length]
b = orders_q.tolist()

instance = MVP(Ws, Cs, Qs, ws, b)
afg = AFG(instance)
# Out:
# VPSolver 3.1.2, Copyright (C) 2013-2016, Filipe Brandao
# Build (method = -3)
#   #dp: 148
#   Step-3' Graph: 97 vertices and 2383 arcs (0.00s)
#   Step-4' Graph: 91 vertices and 215 arcs (0.00s)
#   #V4/#V3 = 0.94
#   #A4/#A3 = 0.09
# Ready! (0.00s)

# %% [markdown]
# # Solution

# %%
output, solution = VPSolver.script("vpsolver_scip.sh", instance)
# Out:
# Copyright (C) 2013-2016, Filipe Brandao
#
# >>> vbp2afg...
# VPSolver 3.1.2, Copyright (C) 2013-2016, Filipe Brandao
# Build (method = -3)
#   #dp: 148
#   Step-3' Graph: 97 vertices and 2383 arcs (0.00s)
#   Step-4' Graph: 91 vertices and 215 arcs (0.00s)
#   #V4/#V3 = 0.94
#   #A4/#A3 = 0.09
# Ready! (0.00s)
#
# >>> afg2mps...
# VPSolver 3.1.2, Copyright (C) 2013-2016, Filipe Brandao
# Generating the .MPS model...DONE!
#
# >>> solving the MIP model using SCIP...
# Note: different parameter settings may improve the performance substantially!
# SCIP version 6.0.0 [precision: 8 byte] [memory: block] [mode: optimized] [LP solver: SoPlex 4.0.0] [GitHash: 77d3bc8]
# Copyright (C) 2002-2018 Konrad-Zuse-Zentrum fuer Informationstechnik Berlin (ZIB)
#
# External codes:
#   Readline EditLine w  GNU library for command line editing (gnu.org/s/readline)
#   SoPlex 4.0.0         Linear Programming Solver developed at Zuse Institute Berlin (soplex.zib.de) [GitHash: 82cab95]
#   CppAD 20180000.0     Algorithmic Differentiation of C++ algorithms developed by B. Bell (www.coin-or.org/CppAD)
#   ZLIB 1.2.11          General purpose compression library by J. Gailly and M. Adler (zlib.net)
#   GMP 6.2.0            GNU Multiple Precision Arithmetic Library developed by T. Granlund (gmplib.org)
#
# user parameter file <scip.set> not found - using default parameters
#
#
# read problem </var/folders/q5/2gv25gs93z72n_55js_2dfhc0000gn/T/XXXXXXXXXX.aJ49xWRK/model.mps>
# ============
#
# original problem has 215 variables (0 bin, 215 int, 0 impl, 0 cont) and 97 constraints
#
# presolving:
# (round 1, fast)       4 del vars, 4 del conss, 0 add conss, 49 chg bounds, 0 chg sides, 0 chg coeffs, 0 upgd conss, 0 impls, 1 clqs
# (round 2, fast)       4 del vars, 4 del conss, 0 add conss, 55 chg bounds, 0 chg sides, 0 chg coeffs, 0 upgd conss, 0 impls, 1 clqs
# (round 3, fast)       4 del vars, 4 del conss, 0 add conss, 57 chg bounds, 0 chg sides, 0 chg coeffs, 0 upgd conss, 0 impls, 1 clqs
# (round 4, fast)       4 del vars, 4 del conss, 0 add conss, 71 chg bounds, 0 chg sides, 0 chg coeffs, 0 upgd conss, 0 impls, 1 clqs
# (round 5, fast)       4 del vars, 4 del conss, 0 add conss, 80 chg bounds, 0 chg sides, 0 chg coeffs, 0 upgd conss, 0 impls, 1 clqs
# (round 6, fast)       5 del vars, 5 del conss, 0 add conss, 89 chg bounds, 0 chg sides, 0 chg coeffs, 0 upgd conss, 0 impls, 1 clqs
# (round 7, fast)       6 del vars, 6 del conss, 0 add conss, 90 chg bounds, 0 chg sides, 0 chg coeffs, 0 upgd conss, 0 impls, 1 clqs
# (round 8, exhaustive) 6 del vars, 6 del conss, 0 add conss, 93 chg bounds, 0 chg sides, 0 chg coeffs, 0 upgd conss, 0 impls, 1 clqs
# (round 9, fast)       7 del vars, 7 del conss, 0 add conss, 97 chg bounds, 0 chg sides, 0 chg coeffs, 0 upgd conss, 0 impls, 1 clqs
# (round 10, fast)       8 del vars, 8 del conss, 0 add conss, 100 chg bounds, 0 chg sides, 0 chg coeffs, 0 upgd conss, 0 impls, 1 clqs
# (round 11, fast)       8 del vars, 8 del conss, 0 add conss, 102 chg bounds, 0 chg sides, 0 chg coeffs, 0 upgd conss, 0 impls, 1 clqs
# (round 12, fast)       9 del vars, 9 del conss, 0 add conss, 103 chg bounds, 0 chg sides, 0 chg coeffs, 0 upgd conss, 0 impls, 1 clqs
# (round 13, fast)       10 del vars, 10 del conss, 0 add conss, 104 chg bounds, 0 chg sides, 0 chg coeffs, 0 upgd conss, 0 impls, 1 clqs
# (round 14, exhaustive) 10 del vars, 10 del conss, 0 add conss, 106 chg bounds, 0 chg sides, 0 chg coeffs, 0 upgd conss, 0 impls, 1 clqs
# (round 15, fast)       10 del vars, 10 del conss, 0 add conss, 108 chg bounds, 0 chg sides, 0 chg coeffs, 0 upgd conss, 0 impls, 1 clqs
# (round 16, fast)       11 del vars, 11 del conss, 0 add conss, 109 chg bounds, 0 chg sides, 0 chg coeffs, 0 upgd conss, 0 impls, 1 clqs
# (round 17, fast)       11 del vars, 11 del conss, 0 add conss, 111 chg bounds, 0 chg sides, 0 chg coeffs, 0 upgd conss, 0 impls, 1 clqs
# (round 18, fast)       12 del vars, 12 del conss, 0 add conss, 112 chg bounds, 0 chg sides, 0 chg coeffs, 0 upgd conss, 0 impls, 1 clqs
# (round 19, fast)       13 del vars, 13 del conss, 0 add conss, 113 chg bounds, 0 chg sides, 0 chg coeffs, 0 upgd conss, 0 impls, 1 clqs
# (round 20, exhaustive) 13 del vars, 13 del conss, 0 add conss, 115 chg bounds, 0 chg sides, 0 chg coeffs, 0 upgd conss, 0 impls, 1 clqs
# (round 21, fast)       14 del vars, 14 del conss, 0 add conss, 116 chg bounds, 0 chg sides, 0 chg coeffs, 0 upgd conss, 0 impls, 1 clqs
# (round 22, fast)       14 del vars, 14 del conss, 0 add conss, 118 chg bounds, 0 chg sides, 0 chg coeffs, 0 upgd conss, 0 impls, 1 clqs
# (round 23, fast)       15 del vars, 15 del conss, 0 add conss, 119 chg bounds, 0 chg sides, 0 chg coeffs, 0 upgd conss, 0 impls, 1 clqs
# (round 24, exhaustive) 15 del vars, 15 del conss, 0 add conss, 122 chg bounds, 0 chg sides, 0 chg coeffs, 0 upgd conss, 0 impls, 1 clqs
# (round 25, exhaustive) 15 del vars, 15 del conss, 0 add conss, 124 chg bounds, 0 chg sides, 0 chg coeffs, 0 upgd conss, 0 impls, 1 clqs
# (round 26, exhaustive) 15 del vars, 15 del conss, 0 add conss, 126 chg bounds, 0 chg sides, 0 chg coeffs, 0 upgd conss, 0 impls, 1 clqs
# (round 27, exhaustive) 15 del vars, 15 del conss, 0 add conss, 128 chg bounds, 0 chg sides, 0 chg coeffs, 0 upgd conss, 0 impls, 1 clqs
# (round 28, exhaustive) 15 del vars, 15 del conss, 0 add conss, 130 chg bounds, 0 chg sides, 0 chg coeffs, 0 upgd conss, 0 impls, 1 clqs
# (round 29, fast)       16 del vars, 16 del conss, 0 add conss, 131 chg bounds, 0 chg sides, 0 chg coeffs, 0 upgd conss, 0 impls, 1 clqs
# (round 30, fast)       17 del vars, 17 del conss, 0 add conss, 132 chg bounds, 0 chg sides, 0 chg coeffs, 0 upgd conss, 0 impls, 1 clqs
# (round 31, fast)       17 del vars, 17 del conss, 0 add conss, 134 chg bounds, 0 chg sides, 0 chg coeffs, 0 upgd conss, 0 impls, 1 clqs
# (round 32, exhaustive) 17 del vars, 17 del conss, 0 add conss, 136 chg bounds, 0 chg sides, 0 chg coeffs, 0 upgd conss, 0 impls, 1 clqs
# (round 33, exhaustive) 17 del vars, 17 del conss, 0 add conss, 138 chg bounds, 0 chg sides, 0 chg coeffs, 0 upgd conss, 0 impls, 1 clqs
# (round 34, exhaustive) 17 del vars, 17 del conss, 0 add conss, 138 chg bounds, 0 chg sides, 0 chg coeffs, 1 upgd conss, 0 impls, 1 clqs
#    (0.0s) probing cycle finished: starting next cycle
# (round 35, exhaustive) 17 del vars, 17 del conss, 0 add conss, 143 chg bounds, 0 chg sides, 0 chg coeffs, 1 upgd conss, 454 impls, 1 clqs
#    (0.0s) probing cycle finished: starting next cycle
# presolving (36 rounds: 36 fast, 13 medium, 13 exhaustive):
#  17 deleted vars, 17 deleted constraints, 0 added constraints, 143 tightened bounds, 0 added holes, 0 changed sides, 0 changed coefficients
#  454 implications, 1 cliques
# presolved problem has 198 variables (47 bin, 151 int, 0 impl, 0 cont) and 80 constraints
#       1 constraints of type <setppc>
#      79 constraints of type <linear>
# transformed objective value is always integral (scale: 1)
# Presolving Time: 0.02
#
#  time | node  | left  |LP iter|LP it/n| mem |mdpt |frac |vars |cons |cols |rows |cuts |confs|strbr|  dualbound   | primalbound  |  gap
#   0.0s|     1 |     0 |   234 |     - |2191k|   0 |  23 | 198 |  80 | 198 |  80 |   0 |   0 |   0 | 3.533333e+01 |      --      |    Inf
# R 0.0s|     1 |     0 |   234 |     - |2198k|   0 |   - | 198 |  80 | 198 |  80 |   0 |   0 |   0 | 3.533333e+01 | 3.600000e+01 |   1.89%
#   0.0s|     1 |     0 |   234 |     - |2198k|   0 |   - | 198 |  80 | 198 |  80 |   0 |   0 |   0 | 3.533333e+01 | 3.600000e+01 |   1.89%
#   0.0s|     1 |     0 |   234 |     - |2198k|   0 |   - | 198 |  80 | 198 |  80 |   0 |   0 |   0 | 3.600000e+01 | 3.600000e+01 |   0.00%
#
# SCIP Status        : problem is solved [optimal solution found]
# Solving Time (sec) : 0.04
# Solving Nodes      : 1
# Primal Bound       : +3.60000000000000e+01 (1 solutions)
# Dual Bound         : +3.60000000000000e+01
# Gap                : 0.00 %
#
#
# written solution information to file </var/folders/q5/2gv25gs93z72n_55js_2dfhc0000gn/T/XXXXXXXXXX.aJ49xWRK/vars.sol>
#
#
#
# >>> vbpsol...
# VPSolver 3.1.2, Copyright (C) 2013-2016, Filipe Brandao
# Objective: 36
# Solution:
# Bins of type 1: 0
# Bins of type 2: 0
# Bins of type 3: 0
# Bins of type 4: 0
# Bins of type 5: 0
# Bins of type 6: 0
# Bins of type 7: 0
# Bins of type 8: 0
# Bins of type 9: 0
# Bins of type 10: 1
# 1 x [i=3, i=4]
# Bins of type 11: 1
# 1 x [i=2, i=5]
# Bins of type 12: 1
# 1 x [i=3, i=5]
# Bins of type 13: 1
# 1 x [i=3, i=5]
# Bins of type 14: 1
# 1 x [i=1, i=6]
# Bins of type 15: 1
# 1 x [i=1, i=6]
# Bins of type 16: 1
# 1 x [i=1, i=3, i=4]
# Bins of type 17: 1
# 1 x [i=4, i=4]
# Bins of type 18: 1
# 1 x [i=4, i=4]
# Bins of type 19: 1
# 1 x [i=2, i=6]
# Bins of type 20: 1
# 1 x [i=3, i=6]
# Bins of type 21: 1
# 1 x [i=3, i=6]
# Bins of type 22: 1
# 1 x [i=3, i=6]
# Bins of type 23: 1
# 1 x [i=3, i=6]
# Bins of type 24: 1
# 1 x [i=3, i=6]
# Bins of type 25: 1
# 1 x [i=3, i=6]
# Bins of type 26: 1
# 1 x [i=3, i=6]
# Bins of type 27: 1
# 1 x [i=3, i=6]
# Bins of type 28: 1
# 1 x [i=4, i=5]
# Bins of type 29: 1
# 1 x [i=4, i=5]
# Bins of type 30: 1
# 1 x [i=4, i=5]
# Bins of type 31: 1
# 1 x [i=4, i=5]
# Bins of type 32: 1
# 1 x [i=4, i=5]
# Bins of type 33: 1
# 1 x [i=4, i=5]
# Bins of type 34: 1
# 1 x [i=4, i=5]
# Bins of type 35: 1
# 1 x [i=1, i=1, i=6]
# Bins of type 36: 1
# 1 x [i=1, i=1, i=2, i=2, i=2]
# Bins of type 37: 1
# 1 x [i=1, i=1, i=2, i=2, i=2]
# Bins of type 38: 1
# 1 x [i=1, i=1, i=2, i=2, i=2]
# Bins of type 39: 1
# 1 x [i=1, i=1, i=2, i=2, i=2]
# Bins of type 40: 1
# 1 x [i=4, i=6]
# Bins of type 41: 1
# 1 x [i=2, i=3, i=6]
# Bins of type 42: 1
# 1 x [i=3, i=5]
# Bins of type 43: 1
# 1 x [i=1, i=5, i=5]
# Bins of type 44: 1
# 1 x [i=3, i=5, i=5]
# Bins of type 45: 1
# 1 x [i=1, i=4, i=6]

# %%
df_1 = pd.DataFrame(solution[1])
df_1.columns = ['raw_solution']
bin_len = [44, 53, 60, 105, 120, 157]

# %%
def get_scrap(x):
    if x < min(bin_len):
        return x
    else:
        return 0

def get_bin_size(x):
    if x != None:
        x = x[1]
        result = []
        for i in x:
            result.append(bin_len[i[0]])
        return result
    else:
        return 0

def get_leftover(x):
    if x[1] == 0:
        return 0
    else:
        return x[0] - sum(x[1])
    
df_1['wire_len'] = actual_length
df_1['bins'] = df_1.apply(lambda x: get_bin_size(x[0]), axis = 1)
df_1['wire_len'] = df_1.apply(lambda x: (x[1][0]), axis = 1)
df_1 = df_1.drop(columns='raw_solution')
df_1['leftover'] = df_1.apply(lambda x: get_leftover(x) ,axis = 1)
df_1['scrap'] = df_1.apply(lambda x: get_scrap(x[2]), axis=1)

# %%
df_1
# Out:
#     wire_len                  bins  leftover  scrap
# 0         94                     0         0      0
# 1        105                     0         0      0
# 2        107                     0         0      0
# 3        118                     0         0      0
# 4        124                     0         0      0
# 5        159                     0         0      0
# 6        159                     0         0      0
# 7        160                     0         0      0
# 8        165                     0         0      0
# 9        167             [60, 105]         2      2
# 10       177             [53, 120]         4      4
# 11       181             [60, 120]         1      1
# 12       185             [60, 120]         5      5
# 13       202             [44, 157]         1      1
# 14       207             [44, 157]         6      6
# 15       209         [44, 60, 105]         0      0
# 16       211            [105, 105]         1      1
# 17       215            [105, 105]         5      5
# 18       215             [53, 157]         5      5
# 19       217             [60, 157]         0      0
# 20       217             [60, 157]         0      0
# 21       218             [60, 157]         1      1
# 22       218             [60, 157]         1      1
# 23       218             [60, 157]         1      1
# 24       218             [60, 157]         1      1
# 25       220             [60, 157]         3      3
# 26       222             [60, 157]         5      5
# 27       225            [105, 120]         0      0
# 28       226            [105, 120]         1      1
# 29       226            [105, 120]         1      1
# 30       226            [105, 120]         1      1
# 31       227            [105, 120]         2      2
# 32       230            [105, 120]         5      5
# 33       235            [105, 120]        10     10
# 34       246         [44, 44, 157]         1      1
# 35       247  [44, 44, 53, 53, 53]         0      0
# 36       249  [44, 44, 53, 53, 53]         2      2
# 37       250  [44, 44, 53, 53, 53]         3      3
# 38       250  [44, 44, 53, 53, 53]         3      3
# 39       265            [105, 157]         3      3
# 40       271         [53, 60, 157]         1      1
# 41       286             [60, 120]       106      0
# 42       290        [44, 120, 120]         6      6
# 43       300        [60, 120, 120]         0      0
# 44       308        [44, 105, 157]         2      2

# %%
bins_count = df_1['bins'].values.tolist()
bins_count = [i for i in bins_count if i != 0]

bin_times = sum(bins_count, [])
bin_dict = {}
for i in bin_times:
    if i not in bin_dict:
        bin_dict[i] = 1
    else:
        bin_dict[i] += 1

# %%
bin_dict
# Out:
# {60: 15, 105: 15, 53: 15, 120: 15, 44: 15, 157: 15}

# %%
df_1['scrap'].sum()
# Out:
# 83

# %%
df_1.to_excel('Big_input_results_PySCIP.xlsx')
